# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('galaxy_users.csv')

# %% [markdown]
# ### Q1

# %%
df1 = df.copy()
df1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df1.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
ser_list = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies']

# %% [markdown]
# 1 if 조건 else 0 if 조건 else np.nan

# %%
df1.loc[:,ser_list]= df1.loc[:,ser_list].applymap(lambda x : 1 if x =='Yes' else 0 if x == 'No' else np.nan)
df1.shape
# Out:
# (7032, 21)

# %% [markdown]
# df.dropna(subset = )

# %%
df2=df1.dropna(subset=ser_list).copy()
df2.shape
# Out:
# (5512, 21)

# %%
df2['ser_AMT'] = df2.loc[:,ser_list].sum(axis=1)

# %%
df2['ser_AMT'].value_counts()
# Out:
# ser_AMT
# 3.0    1117
# 2.0    1033
# 1.0     966
# 4.0     850
# 0.0     693
# 5.0     569
# 6.0     284
# Name: count, dtype: int64

# %%
df2['ser_AMT'].value_counts()[1]/df2['ser_AMT'].value_counts()[6]
# Out:
# 3.4014084507042255

# %% [markdown]
# ### Q2

# %%
df2=df.copy()

# %% [markdown]
# // 몫 구하기
#
# 몫, 나머지 = divmod(a,b)

# %%
df2['use_month'] = df2['TotalCharges']//df2['MonthlyCharges']

# %%
ans3 = df2[['tenure','MonthlyCharges','use_month']].corr()

# %%
pd.Series(ans3.values.reshape(-1)).abs().sort_values(ascending=False).unique()[1]
# Out:
# 0.9988308750302998

# %%
df2[['tenure','MonthlyCharges','use_month']].corr().nlargest(2,columns=['tenure','use_month'])
# Out:
#              tenure  MonthlyCharges  use_month
# tenure     1.000000        0.246862   0.998831
# use_month  0.998831        0.246164   1.000000

# %% [markdown]
# ### Q3

# %%
df3=df.copy()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
X_list = ["SeniorCitizen", "Partner", "Dependents", "tenure", "MonthlyCharges", "TotalCharges",
           "OnlineSecurity", "OnlineBackup", "DeviceProtection", "TechSupport", "StreamingMovies", 
           "PaperlessBilling"]

# %%
df3_1 = df3.loc[:,X_list].copy()
df3.loc[:,X_list]
# Out:
#       SeniorCitizen Partner Dependents  tenure  MonthlyCharges  TotalCharges  \
# 0                 0     Yes         No       1           29.85         29.85
# 1                 0      No         No      34           56.95       1889.50
# 2                 0      No         No       2           53.85        108.15
# 3                 0      No         No      45           42.30       1840.75
# 4                 0      No         No       2           70.70        151.65
# ...             ...     ...        ...     ...             ...           ...
# 7027              0     Yes        Yes      24           84.80       1990.50
# 7028              0     Yes        Yes      72          103.20       7362.90
# 7029              0     Yes        Yes      11           29.60        346.45
# 7030              1     Yes         No       4           74.40        306.60
# 7031              0      No         No      66          105.65       6844.50
#
# ...

# %%
Cat_list = ["Partner", "Dependents", 
           "OnlineSecurity", "OnlineBackup", "DeviceProtection", "TechSupport", "StreamingMovies", 
           "PaperlessBilling"]

# %%
df3_1.loc[:,Cat_list] =df3_1.loc[:,Cat_list].applymap(lambda x : 1 if x == 'Yes' else 0 if x == 'No' else -1)
df3_1
# Out:
#       SeniorCitizen Partner Dependents  tenure  MonthlyCharges  TotalCharges  \
# 0                 0       1          0       1           29.85         29.85
# 1                 0       0          0      34           56.95       1889.50
# 2                 0       0          0       2           53.85        108.15
# 3                 0       0          0      45           42.30       1840.75
# 4                 0       0          0       2           70.70        151.65
# ...             ...     ...        ...     ...             ...           ...
# 7027              0       1          1      24           84.80       1990.50
# 7028              0       1          1      72          103.20       7362.90
# 7029              0       1          1      11           29.60        346.45
# 7030              1       1          0       4           74.40        306.60
# 7031              0       0          0      66          105.65       6844.50
#
# ...

# %%
df3_1['Churn']=df3['Churn'].map(lambda x : 1 if x == 'Yes' else 0 if x == 'No' else -1)
df3_1
# Out:
#       SeniorCitizen Partner Dependents  tenure  MonthlyCharges  TotalCharges  \
# 0                 0       1          0       1           29.85         29.85
# 1                 0       0          0      34           56.95       1889.50
# 2                 0       0          0       2           53.85        108.15
# 3                 0       0          0      45           42.30       1840.75
# 4                 0       0          0       2           70.70        151.65
# ...             ...     ...        ...     ...             ...           ...
# 7027              0       1          1      24           84.80       1990.50
# 7028              0       1          1      72          103.20       7362.90
# 7029              0       1          1      11           29.60        346.45
# 7030              1       1          0       4           74.40        306.60
# 7031              0       0          0      66          105.65       6844.50
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(df3_1,test_size=0.3,random_state=123)
train.shape, test.shape
# Out:
# ((4922, 13), (2110, 13))

# %%
from sklearn.preprocessing import StandardScaler

# %%
mySDS = StandardScaler()
mySDS.fit(train[X_list])
# Out:
# StandardScaler()

# %%
train_SS = mySDS.transform(train[X_list])
test_SS = mySDS.transform(test[X_list])

# %%
from sklearn.linear_model import LogisticRegression

# %%
myLR = LogisticRegression(random_state=123)

# %%
myLR.fit(train[X_list],train['Churn'])
# Out:
# LogisticRegression(random_state=123)

# %%
y_pred =myLR.predict(test[X_list])
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import f1_score

# %%
f1_score(test['Churn'],y_pred)
# Out:
# 0.5529411764705883
